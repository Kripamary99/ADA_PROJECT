# %%
import pandas as pd
df1=pd.read_csv('/content/Student Stress and Housing Styles Survey  (Responses) - Form Responses 1 (2).csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Timestamp         82 non-null     object
#  1   Email             82 non-null     object
#  2   Name              82 non-null     object
#  3   Age               82 non-null     int64
#  4   Gender            82 non-null     object
#  5   Year              82 non-null     object
#  6   Type              82 non-null     object
#  7   Roommates         82 non-null     int64
#  8   Rela_with_roomte  82 non-null     object
#  9   house_env         82 non-null     object
#  10  Proximity         82 non-null     int64
#  11  facilities        82 non-null     object
#  12  Difficulty_level  82 non-null     object
#  13  study             82 non-null     float64
#  14  study_env         82 non-null     object
#  15  perc              82 non-null     float64
# ...

# %%
df1
# Out:
#              Timestamp                                     Email  \
# 0   8/15/2024 12:36:55    marcus.daniel@msam.christuniversity.in
# 1   8/15/2024 12:44:28          gamya.k@msam.christuniversity.in
# 2   8/15/2024 12:47:24    melvin.infant@msam.christuniversity.in
# 3   8/15/2024 12:47:43              kirantreesakalayil@gmail.com
# 4   8/15/2024 12:51:31               meenakshinambiar6@gmail.com
# ..                 ...                                       ...
# 77  8/15/2024 16:51:10              rachelmaryofficial@gmail.com
# 78  8/15/2024 16:57:25  parameshwarijaiganesanjaiganes@gmail.com
# 79  8/15/2024 16:58:02               mahalakshmi720037@gmail.com
# 80  8/15/2024 17:14:00                       sirajf251@gmail.com
# 81  8/15/2024 17:15:38                  rajeshvijay252@gmail.com
#
#                   Name  Age  Gender                                    Year  \
# 0        Marcus daniel   22    Male  Graduate (Master’s/Ph.D./Postgraduate)
# ...

# %%
df=df1[['Age','Gender','Type','Roommates','Rela_with_roomte','house_env','Proximity','Difficulty_level','study','perc','stress_level','stress_trig','support','Frequency','cost','fin_stress_level']]
df
# Out:
#     Age  Gender                 Type  Roommates Rela_with_roomte house_env  \
# 0    22    Male       Shared housing          3         Positive  Moderate
# 1    22  Female    Paying guest (pg)          2          Neutral  Moderate
# 2    21    Male       Shared housing          3         Positive     Quiet
# 3    23  Female   Living with family          7         Positive     Quiet
# 4    21  Female               Hostel          2         Positive  Moderate
# ..  ...     ...                  ...        ...              ...       ...
# 77   25  Female       Shared housing          1         Positive     Quiet
# 78   21  Female       Shared housing          4         Positive  Moderate
# 79   19  Female   Living with family          0          Neutral  Moderate
# 80   16  Female  On-campus dormitory          1         Positive  Moderate
# 81   18    Male   Living with family          4         Positive     Quiet
#
#     Proximity Difficulty_level  study  perc  stress_level  \
# ...

# %%
df['Type'].unique()
# Out:
# array(['Shared housing', 'Paying guest (pg)', 'Living with family',
#        'Hostel', 'Off-campus apartment', 'On-campus dormitory',
#        'Hostel off campus ', 'paying guest', 'Hostel '], dtype=object)

# %%
ind=df[(df['Type']=='Paying guest (pg)') | (df['Type']=='Off-campus apartment') | (df['Type']=='paying guest') | (df['Type']=='Hostel off campus ')]
for i in ind.index:
  df.loc[i,'Type']='Outside hostel'
df['Type'].unique()
# Out:
# array(['Shared housing', 'Outside hostel', 'Living with family', 'Hostel',
#        'On-campus dormitory', 'Hostel '], dtype=object)

# %%
ind=df[(df['Type']=='Hostel') | (df['Type']=='On-campus dormitory') | (df['Type']=='Hostel ')]
for i in ind.index:
  df.loc[i,'Type']='Inside hostel'
df['Type'].unique()
# Out:
# array(['Shared housing', 'Outside hostel', 'Living with family',
#        'Inside hostel'], dtype=object)

# %%
df['stress_trig'].unique()
# Out:
# array(['Academic, Social', 'Academic, Financial', 'Gf', 'Academic',
#        'Academic, Financial, Family', 'Nothing', 'Social, Financial',
#        'Financial', 'Financial, Family', 'Family', 'Academic, Family',
#        'Academic, Social, Financial, Family',
#        'Academic, Social, Financial', 'Social',
#        'Academic, Social, Family, ', 'Social, Financial, Family',
#        'Family, ', 'No', 'Academic, Social, Family'], dtype=object)

# %% [markdown]
# Here the field 'stress_trig' has multiple combinations of the options specified in the form. Simply label encoding everything will give diiferent values for the same(for example: some entry will have 'Academic, Family' and some will have 'Academic, Social' both has 2 reasons for stress triggering but the label encoder will encode both as different). Hence we calculate the commas in each entry and add 1 to it (for example: if one entry has only 'Academic' the code will calculate the commas in it, since there is no comma it will be taken as 0 and 1 will be added to it, if one entry has 'Academic, Family' there is 1 comma and it will be taken and after adding 1 the value of that entry will be 2, since there are 2 reasons for stress). Hence that we would be able to calculate the amount of factors.

# %%
df.shape
# Out:
# (82, 16)

# %%
count=[]
for i in range(0,82):
  count.append(df['stress_trig'][i].count(',')+1)
count
# Out:
# [2,
#  2,
#  1,
#  1,
#  3,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  2,
#  1,
#  3,
#  4,
#  2,
#  4,
#  4,
#  2,
#  1,
#  3,
#  4,
#  2,
#  1,
#  1,
#  1,
#  1,
#  2,
#  1,
#  4,
#  3,
#  1,
#  1,
#  1,
#  2,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  2,
#  4,
#  1,
#  2,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  2,
#  4,
#  1,
#  1,
#  2,
#  1,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  2,
#  1,
#  1,
#  1]

# %%
df['stress_trig']=count
df['stress_trig']
# Out:
# <ipython-input-157-22629f8da916>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['stress_trig']=count
# 0     2
# 1     2
# 2     1
# 3     1
# 4     3
#      ..
# 77    3
# 78    2
# 79    1
# 80    1
# 81    1
# Name: stress_trig, Length: 82, dtype: int64

# %%
df['cost'].unique()
# Out:
# array(['7000', '9000', '10000', '10,000', '20000', '6000', '5000', '4000',
#        '25000', '8500', '3000', '8000', '9500', '3500', '17000', '11000',
#        '1700', '15000', 'Mortgage ', '0', '7500', '5800', 'No', '30000',
#        '7', 'Rent', '16000', '2000', '12000', '𝐦𝐨𝐫𝐭𝐠𝐚𝐠𝐞', 'Mortgage',
#        'Rent '], dtype=object)

# %%
ind=df[(df['cost']=='Rent') | (df['cost']=='Mortgage ') | (df['cost']=='No') | (df['cost']=='𝐦𝐨𝐫𝐭𝐠𝐚𝐠𝐞') | (df['cost']=='Mortgage') | (df['cost']=='Rent ')]
for i in ind.index:
  df.loc[i,'cost']=0
df['cost'].unique()
# Out:
# array(['7000', '9000', '10000', '10,000', '20000', '6000', '5000', '4000',
#        '25000', '8500', '3000', '8000', '9500', '3500', '17000', '11000',
#        '1700', '15000', 0, '0', '7500', '5800', '30000', '7', '16000',
#        '2000', '12000'], dtype=object)

# %%
ind=df[(df['cost']==0) | (df['cost']=='0') | (df['cost']==7) | (df['cost']=='7')]
for i in ind.index:
  df.loc[i,'cost']=9000
df['cost'].unique()
# Out:
# array(['7000', '9000', '10000', '10,000', '20000', '6000', '5000', '4000',
#        '25000', '8500', '3000', '8000', '9500', '3500', '17000', '11000',
#        '1700', '15000', 9000, '7500', '5800', '30000', '16000', '2000',
#        '12000'], dtype=object)

# %%
ind=df[df['cost']=='10,000']
for i in ind.index:
  df.loc[i,'cost']=10000
df['cost'].unique()
# Out:
# array(['7000', '9000', '10000', 10000, '20000', '6000', '5000', '4000',
#        '25000', '8500', '3000', '8000', '9500', '3500', '17000', '11000',
#        '1700', '15000', 9000, '7500', '5800', '30000', '16000', '2000',
#        '12000'], dtype=object)

# %%
df['cost'] = df['cost'].astype('int')
df['cost'].dtype
# Out:
# <ipython-input-162-03cdc17902ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cost'] = df['cost'].astype('int')
# dtype('int64')

# %%
df['cost'] = df['cost'] / 1000
df['cost']
# Out:
# <ipython-input-163-fa39ad7bf274>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cost'] = df['cost'] / 1000
# 0      7.0
# 1      7.0
# 2      9.0
# 3     10.0
# 4     10.0
#       ...
# 77    11.0
# 78     9.0
# 79     3.0
# 80     9.0
# 81     2.0
# Name: cost, Length: 82, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
object_cols = df.select_dtypes(include=['object']).columns
label_encoder = LabelEncoder()
for col in object_cols:
    df[col] = label_encoder.fit_transform(df[col])
df
# Out:
# <ipython-input-164-736c10456973>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# <ipython-input-164-736c10456973>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# <ipython-input-164-736c10456973>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.isna().sum()
# Out:
# Age                 0
# Gender              0
# Type                0
# Roommates           0
# Rela_with_roomte    0
# house_env           0
# Proximity           0
# Difficulty_level    0
# study               0
# perc                0
# stress_level        2
# stress_trig         0
# support             0
# Frequency           0
# cost                0
# fin_stress_level    0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df.isna().sum()
# Out:
# <ipython-input-166-80ca06535dfe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(), inplace=True)
# Age                 0
# Gender              0
# Type                0
# Roommates           0
# Rela_with_roomte    0
# house_env           0
# Proximity           0
# Difficulty_level    0
# study               0
# perc                0
# stress_level        0
# stress_trig         0
# support             0
# Frequency           0
# cost                0
# fin_stress_level    0
# dtype: int64

# %%
df = df.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               82 non-null     int64
#  1   Gender            82 non-null     int64
#  2   Type              82 non-null     int64
#  3   Roommates         82 non-null     int64
#  4   Rela_with_roomte  82 non-null     int64
#  5   house_env         82 non-null     int64
#  6   Proximity         82 non-null     int64
#  7   Difficulty_level  82 non-null     int64
#  8   study             82 non-null     int64
#  9   perc              82 non-null     int64
#  10  stress_level      82 non-null     int64
#  11  stress_trig       82 non-null     int64
#  12  support           82 non-null     int64
#  13  Frequency         82 non-null     int64
#  14  cost              82 non-null     int64
#  15  fin_stress_level  82 non-null     int64
# dtypes: int64(16)
# memory usage: 10.4 KB

# %%
df
# Out:
#     Age  Gender  Type  Roommates  Rela_with_roomte  house_env  Proximity  \
# 0    22       1     3          3                 2          0         10
# 1    22       0     2          2                 1          0         10
# 2    21       1     3          3                 2          2          5
# 3    23       0     1          7                 2          2         45
# 4    21       0     0          2                 2          0          7
# ..  ...     ...   ...        ...               ...        ...        ...
# 77   25       0     3          1                 2          2         15
# 78   21       0     3          4                 2          0          5
# 79   19       0     1          0                 1          0          5
# 80   16       0     0          1                 2          0         60
# 81   18       1     1          4                 2          2         60
#
#     Difficulty_level  study  perc  stress_level  stress_trig  support  \
# ...

# %%
df.describe()
# Out:
#              Age     Gender       Type   Roommates  Rela_with_roomte  \
# count  82.000000  82.000000  82.000000   82.000000         82.000000
# mean   21.024390   0.341463   1.390244    3.939024          1.634146
# std     2.837037   0.477119   0.939610   11.942607          0.555826
# min    16.000000   0.000000   0.000000    0.000000          0.000000
# 25%    19.000000   0.000000   1.000000    1.000000          1.000000
# 50%    21.000000   0.000000   1.000000    2.000000          2.000000
# 75%    22.750000   1.000000   2.000000    4.000000          2.000000
# max    34.000000   1.000000   3.000000  108.000000          2.000000
#
#        house_env   Proximity  Difficulty_level      study        perc  \
# count  82.000000   82.000000         82.000000  82.000000   82.000000
# mean    0.878049   23.317073          1.451220  12.670732   73.378049
# std     0.973605   21.812262          0.891004  11.750550   17.169914
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
import math
lr=LinearRegression()
y=df[['stress_level']]
df.drop('stress_level',axis=1,inplace=True)
x=df
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=2)
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# MULTI-LINEAR REGRESSION

# %%
ypred=lr.predict(xtest)
mse_lr=mean_squared_error(ytest,ypred)
print("MSE: ",mse_lr)
mae_lr=mean_absolute_error(ytest,ypred)
print("MAE: ",mae_lr)
rmse_lr = math.sqrt(mse_lr)
print("RMSE: ",rmse_lr)
r2 = r2_score(ytest, ypred)
print("R-squared:", r2)
n = xtest.shape[0]
p = xtest.shape[1]
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
print("Adjusted R-squared:", adjusted_r2)
print(lr.coef_)
print(lr.intercept_)
# Out:
# MSE:  4.052745802873846
# MAE:  1.7603773189133396
# RMSE:  2.013143264368894
# R-squared: -0.011436560475424518
# Adjusted R-squared: -15.182984967606792
# [[ 1.09785282e-01  5.37535688e-02 -1.05610080e-01  8.88043142e-03
#   -6.47127329e-01 -4.60061165e-01 -4.11271597e-04  1.99704472e-01
#   -1.33133698e-02 -1.36181202e-03  7.05295542e-01  5.97743133e-02
#    1.74202370e-01  8.26555425e-02  2.11695706e-01]]
# [1.00211876]

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(xtrain, ytrain)
y_pred_rf = rf.predict(xtest)
mse_rf = mean_squared_error(ytest, y_pred_rf)
print("Mean Squared Error (MSE):", mse_rf)
mae_rf = mean_absolute_error(ytest, y_pred_rf)
print("Mean Absolute Error (MAE):", mae_rf)
rmse_rf = math.sqrt(mse_rf)
print("Root Mean Squared Error (RMSE):", rmse_rf)
r2_rf = r2_score(ytest, ypred)
print("R-squared:", r2_rf)
n = xtest.shape[0]
p = xtest.shape[1]
adjusted_r2_rf = 1 - (1 - r2) * (n - 1) / (n - p - 1)
print("Adjusted R-squared:", adjusted_r2_rf)
# Out:
# Mean Squared Error (MSE): 4.1081
# Mean Absolute Error (MAE): 1.4500000000000002
# Root Mean Squared Error (RMSE): 2.0268448386593385
# R-squared: -0.011436560475424518
# Adjusted R-squared: -15.182984967606792
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor
dt_regressor = DecisionTreeRegressor(random_state=42)
dt_regressor.fit(xtrain, ytrain)
y_pred_dt = dt_regressor.predict(xtest)
mse_dt = mean_squared_error(ytest, y_pred_dt)
print("Mean Squared Error (MSE):", mse_dt)
mae_dt = mean_absolute_error(ytest, y_pred_dt)
print("Mean Absolute Error (MAE):", mae_dt)
rmse_dt = math.sqrt(mse_dt)
print("Root Mean Squared Error (RMSE):", rmse_dt)
r2_dt = r2_score(ytest, y_pred_dt)
print("R-squared:", r2_dt)
n = xtest.shape[0]
p = xtest.shape[1]
adjusted_r2_dt = 1 - (1 - r2_dt) * (n - 1) / (n - p - 1)
print("Adjusted R-squared:", adjusted_r2_dt)
# Out:
# Mean Squared Error (MSE): 10.176470588235293
# Mean Absolute Error (MAE): 2.411764705882353
# Root Mean Squared Error (RMSE): 3.19005808540147
# R-squared: -1.5397236614853198
# Adjusted R-squared: -39.63557858376512

# %% [markdown]
# RIDGE RESSION

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(xtrain, ytrain)
y_pred_ridge = ridge.predict(xtest)
mse_ridge = mean_squared_error(ytest, y_pred_ridge)
print("Mean Squared Error (MSE):", mse_ridge)
mae_ridge = mean_absolute_error(ytest, y_pred_ridge)
print("Mean Absolute Error (MAE):", mae_ridge)
rmse_ridge = math.sqrt(mse_ridge)
print("Root Mean Squared Error (RMSE):", rmse_ridge)
r2_ridge = r2_score(ytest, y_pred_ridge)
print("R-squared:", r2_ridge)
n = xtest.shape[0]
p = xtest.shape[1]
adjusted_r2_ridge = 1 - (1 - r2_ridge) * (n - 1) / (n - p - 1)
print("Adjusted R-squared:", adjusted_r2_ridge)
# Out:
# Mean Squared Error (MSE): 4.010524501563155
# Mean Absolute Error (MAE): 1.7531842481798405
# Root Mean Squared Error (RMSE): 2.0026293969586972
# R-squared: -0.000899465416020595
# Adjusted R-squared: -15.01439144665633

# %% [markdown]
# LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.1)
lasso.fit(xtrain, ytrain)
y_pred_lasso = lasso.predict(xtest)
mse_lasso = mean_squared_error(ytest, y_pred_lasso)
print("Mean Squared Error (MSE):", mse_lasso)
mae_lasso = mean_absolute_error(ytest, y_pred_lasso)
print("Mean Absolute Error (MAE):", mae_lasso)
rmse_lasso = math.sqrt(mse_lasso)
print("Root Mean Squared Error (RMSE):", rmse_lasso)
r2_lasso = r2_score(ytest, y_pred_lasso)
print("R-squared:", r2_lasso)
n = xtest.shape[0]
p = xtest.shape[1]
adjusted_r2_lasso = 1 - (1 - r2_lasso) * (n - 1) / (n - p - 1)
print("Adjusted R-squared:", adjusted_r2_lasso)
# Out:
# Mean Squared Error (MSE): 3.567234548262963
# Mean Absolute Error (MAE): 1.6254509483785535
# Root Mean Squared Error (RMSE): 1.8887124048575958
# R-squared: 0.10973161964767142
# Adjusted R-squared: -13.244294085637257

# %%
metrics = {
    'Model': ['Linear Regression', 'Random Forest', 'Decision Tree', 'Polynomial Regression', 'Lasso Regression'],
    'MSE': [mse_lr, mse_rf, mse_dt, mse_ridge, mse_lasso],
    'MAE': [mae_lr, mae_rf, mae_dt, mae_ridge, mae_lasso],
    'RMSE': [rmse_lr, rmse_rf, rmse_dt, rmse_ridge, rmse_lasso],
    'R-squared': [r2, r2_rf, r2_dt, r2_ridge, r2_lasso],
    'Adjusted R-squared': [adjusted_r2, adjusted_r2_rf, adjusted_r2_dt, adjusted_r2_ridge, adjusted_r2_lasso]
}
metrics_df = pd.DataFrame(metrics)
metrics_df.set_index('Model', inplace=True)

# %%
#MSE
metrics_df['MSE'].plot(kind='bar')
plt.title('Mean Squared Error (MSE)')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
# MAE
metrics_df['MAE'].plot(kind='bar')
plt.title('Mean Absolute Error (MAE)')
plt.ylabel('MAE')
# Out:
# Text(0, 0.5, 'MAE')

# %%
# RMSE
metrics_df['RMSE'].plot(kind='bar')
plt.title('Root Mean Squared Error (RMSE)')
plt.ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')

# %%
# R-squared
metrics_df['R-squared'].plot(kind='bar')
plt.title('R-squared')
plt.ylabel('R-squared')
# Out:
# Text(0, 0.5, 'R-squared')

# %%
# Adjusted R-squared
metrics_df['Adjusted R-squared'].plot(kind='bar')
plt.title('Adjusted R-squared')
plt.ylabel('Adjusted R-squared')
# Out:
# Text(0, 0.5, 'Adjusted R-squared')
